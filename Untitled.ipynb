# %%
import requests
f2f_api='5cad6b721f34d4553ab5e6c66a2a112b'

#http://food2fork.com/api/search?key={API_KEY}&q=shredded%20chicken

results=requests.get('http://food2fork.com/api/search?key='+f2f_api+'&q=ham?sort=t')

print results.text[0]
# Out:
# {

# %%
this_dict= results.text

# %%
import ast
this_dict=ast.literal_eval(results.text)

# %%
this_dict
# Out:
# {'count': 30,
#  'recipes': [{'f2f_url': 'http://food2fork.com/view/46938',
#    'image_url': 'http://static.food2fork.com/scalloped1478.jpg',
#    'publisher': 'The Pioneer Woman',
#    'publisher_url': 'http://thepioneerwoman.com',
#    'recipe_id': '46938',
#    'social_rank': 99.99999999839649,
#    'source_url': 'http://thepioneerwoman.com/cooking/2012/04/scalloped-potatoes-and-ham/',
#    'title': 'Scalloped Potatoes and Ham'},
#   {'f2f_url': 'http://food2fork.com/view/36453',
#    'image_url': 'http://static.food2fork.com/pizza292x2007a259a79.jpg',
#    'publisher': 'Simply Recipes',
#    'publisher_url': 'http://simplyrecipes.com',
#    'recipe_id': '36453',
#    'social_rank': 99.99999998833789,
#    'source_url': 'http://www.simplyrecipes.com/recipes/homemade_pizza/',
#    'title': 'Homemade Pizza'},
#   {'f2f_url': 'http://food2fork.com/view/11264',
#    'image_url': 'http://static.food2fork.com/9626561e3b.jpg',
#    'publisher': 'All Recipes',
# ...

# %%
new_req=requests.get('http://food2fork.com/api/get?key='+f2f_api+'&rId='+'56bbdf')

# %%
print new_req.text
# Out:
# {"recipe": {"publisher": "Framed Cooks", "f2f_url": "http://food2fork.com/view/56bbdf", "ingredients": ["1 cup flour", "1 tablespoon sugar", "1/4 teaspoon salt", "1 1/2 cups milk", "4 large eggs", "3 tablespoons melted butter", "9 thin slices ham", "9 eggs", "Chopped fresh parsley", "Directions1. Combine flour, sugar, salt, milk, four eggs and the melted butter in a blender and blend on high for 30 seconds. Let rest for 15 minutes."], "source_url": "http://www.framedcooks.com/2011/02/ham-and-egg-crepe-squares.html", "recipe_id": "56bbdf", "image_url": "http://static.food2fork.com/1175910236_uTQuNM6cf3.jpg", "social_rank": 99.99999933766932, "publisher_url": "http://framedcooks.com", "title": "Ham and Egg Crepe Squares"}}
